# %% [markdown]
# # Heading

# %% [markdown]
# ## Heading

# %% [markdown]
# ### Heading

# %% [markdown]
# #### Heading

# %% [markdown]
# ##### Heading

# %% [markdown]
# ###### Heading

# %% [markdown]
# ## Cokonet

# %%
# Comment

# %% [markdown]
# # <center> Heading

# %% [markdown]
# - one
# - two
# - three

# %% [markdown]
# ![Image 2023-10-25 at 9.59.38 AM.jpeg](attachment:9197fc47-326a-4f9d-b6a9-aa45b32d6d5d.jpeg)

# %% [markdown]
# - kilo
# - hectre
# - miles
# - grams

# %%
### Multiplication
4*5
# Out:
# 20

# %%
5-3
# Out:
# 2

# %% [markdown]
# Coconet Academy
